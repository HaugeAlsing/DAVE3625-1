# %% [markdown]
# Imports and fetching data

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("..\DataFiles\Titanic.csv")

# %% [markdown]
# Exploring the data

# %%
df
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Pclass       1309 non-null   int64
#  2   Name         1309 non-null   object
#  3   Sex          1309 non-null   object
#  4   Age          1046 non-null   float64
#  5   SibSp        1309 non-null   int64
#  6   Parch        1309 non-null   int64
#  7   Ticket       1309 non-null   object
#  8   Fare         1308 non-null   float64
#  9   Cabin        295 non-null    object
#  10  Embarked     1307 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %% [markdown]
# Fixing age as int

# %%
#checking NaN for the age values

ageNa = df["Age"].isnull().sum()

print(f"Amount of NaN values in the Age series: {ageNa}")
# Out:
# Amount of NaN values in the Age series: 263

# %%
# filling age NaN with -1
df["Age"] = df["Age"].fillna(-1)

# casting the type
df["Age"] = df["Age"].astype(int)

# %%
#Checking that filling the age values worked:

ageNa = df["Age"].isnull().sum()

print(f"Amount of NaN values in the Age series: {ageNa}")
# Out:
# Amount of NaN values in the Age series: 0

# %%
#Confirming that the typecast worked:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Pclass       1309 non-null   int64
#  2   Name         1309 non-null   object
#  3   Sex          1309 non-null   object
#  4   Age          1309 non-null   int32
#  5   SibSp        1309 non-null   int64
#  6   Parch        1309 non-null   int64
#  7   Ticket       1309 non-null   object
#  8   Fare         1308 non-null   float64
#  9   Cabin        295 non-null    object
#  10  Embarked     1307 non-null   object
# dtypes: float64(1), int32(1), int64(4), object(5)
# memory usage: 107.5+ KB

# %% [markdown]
# Feature engineering text data

# %%
#Casting to lowercase to make text easier to work with

df["Name"] = df["Name"].apply(lambda x: x.lower())

# %%
def title_extractor(name: str) -> str:
    title = re.search(" [a-z]*\.", name).group(0)
    title = re.sub("\.","",title)
    return title

# %%
df["Name"]
# Out:
# 0                                 braund, mr. owen harris
# 1       cumings, mrs. john bradley (florence briggs th...
# 2                                  heikkinen, miss. laina
# 3            futrelle, mrs. jacques heath (lily may peel)
# 4                                allen, mr. william henry
#                               ...
# 1304                                   spector, mr. woolf
# 1305                         oliva y ocana, dona. fermina
# 1306                         saether, mr. simon sivertsen
# 1307                                  ware, mr. frederick
# 1308                             peter, master. michael j
# Name: Name, Length: 1309, dtype: object

# %%
df["Title"] = df["Name"].apply(lambda x: title_extractor(x))

# %%
df["Title"].value_counts()
# Out:
#  mr          757
#  miss        260
#  mrs         197
#  master       61
#  rev           8
#  dr            8
#  col           4
#  mlle          2
#  major         2
#  ms            2
#  lady          1
#  sir           1
#  mme           1
#  don           1
#  capt          1
#  countess      1
#  jonkheer      1
#  dona          1
# Name: Title, dtype: int64

# %% [markdown]
# Name extraction: Split first and last name

# %%
def last_name_extractor(name: str) -> str:
    last_name = re.search(r"^[a-z]*\,",name)

    try:
        last_name = last_name.group(0)
        last_name = re.sub(r"\,","",last_name)
    except:
        last_name = "Undefined"
    
    return last_name

# %%
def first_name_extractor(name: str) -> str:
    first_name = re.search(r"\. [a-z]*",name)

    try:
        first_name = first_name.group(0)
        first_name = re.sub(r"^\. ","",first_name)
    except:
        first_name = "Undefined"
    
    return first_name

# %%
df["First Name"] = df["Name"].apply(lambda x: first_name_extractor(x))

# %%
df["Last Name"] = df["Name"].apply(lambda x: last_name_extractor(x))

# %% [markdown]
# Making ordinal categories for age (usefull for classification later)

# %%
def age_to_ordinal(age: int) -> int:
    if age < 26:
        return 1
    elif 25 < age < 36:
        return 2
    elif 35 < age < 50:
        return 3
    elif 49 < age < 65:
        return 4
    elif 64 < age < 78:
        return 5
    elif age >= 78:
        return 6

# %%
df["Age Category"] = df["Age"].apply(lambda x: age_to_ordinal(x))

# %%
#looking at the age categories to see the effect
df["Age Category"].value_counts()
# Out:
# 1    706
# 2    281
# 3    212
# 4     97
# 5     12
# 6      1
# Name: Age Category, dtype: int64

# %%
#Plot of age categories on the titanic
df["Age Category"].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
#seeing the whole dataset:
df
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            braund, mr. owen harris
# 1               2       1  cumings, mrs. john bradley (florence briggs th...
# 2               3       3                             heikkinen, miss. laina
# 3               4       1       futrelle, mrs. jacques heath (lily may peel)
# 4               5       3                           allen, mr. william henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 spector, mr. woolf
# 1305         1306       1                       oliva y ocana, dona. fermina
# 1306         1307       3                       saether, mr. simon sivertsen
# 1307         1308       3                                ware, mr. frederick
# 1308         1309       3                           peter, master. michael j
#
# ...

# %% [markdown]
# Dealing with the rest of the NaN values

# %%
#Since 80% ish of cabin is NaN it doesn't make sense just to drop it. Fill out the rest of dataframe with Undefined for NaN values, however do not do this to deal with NaN in numerical columns

#Filling Fare NaN float value of -1.0
df["Fare"] = df["Fare"].fillna(-1.0)

#Filling NaN in the two remaining string columns
df = df.fillna("Undefined")

# %%
df.isna().sum()
# Out:
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# Title           0
# First Name      0
# Last Name       0
# Age Category    0
# dtype: int64

# %%
df
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            braund, mr. owen harris
# 1               2       1  cumings, mrs. john bradley (florence briggs th...
# 2               3       3                             heikkinen, miss. laina
# 3               4       1       futrelle, mrs. jacques heath (lily may peel)
# 4               5       3                           allen, mr. william henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 spector, mr. woolf
# 1305         1306       1                       oliva y ocana, dona. fermina
# 1306         1307       3                       saether, mr. simon sivertsen
# 1307         1308       3                                ware, mr. frederick
# 1308         1309       3                           peter, master. michael j
#
# ...
